# %% [markdown]
# <a href="https://colab.research.google.com/github/awaiskhan005/DEEP-LEARNING-AND-FORECASTING/blob/main/BTC_100_paths_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install properscoring
# Out:
# Collecting properscoring
#   Downloading properscoring-0.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.13.1)
# Downloading properscoring-0.1-py2.py3-none-any.whl (23 kB)
# Installing collected packages: properscoring
# Successfully installed properscoring-0.1

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from sklearn.preprocessing import MinMaxScaler
import json
import datetime
import time
from google.colab import drive
from properscoring import crps_ensemble

# Mount Google Drive
drive.mount('/content/drive')

# Fetch Bitcoin data
def fetch_btc_data(interval='5m', period='30d'):
    btc = yf.download(tickers='BTC-USD', interval=interval, period=period, auto_adjust=True)
    return btc

# Prepare data for LSTM
def prepare_data(df, lookback=50):
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df[['Close']])
    X, y = [], []
    for i in range(lookback, len(scaled_data) - 1):
        X.append(scaled_data[i - lookback:i])
        y.append(scaled_data[i, 0])
    return np.array(X), np.array(y), scaler

# Build LSTM model
def build_lstm_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(100, return_sequences=True),
        Dropout(0.2),
        LSTM(100, return_sequences=True),
        Dropout(0.2),
        LSTM(50, return_sequences=False),
        Dropout(0.2),
        Dense(25),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Predict next 24 hours
def predict_future(model, data, scaler, steps=288, num_paths=100):
    predictions = []
    current_input = data[-1]
    for path_num in range(num_paths):
        print(f"Generating prediction path {path_num+1}/{num_paths}...")
        temp_input = current_input.copy()
        pred_path = []

        for step in range(steps):
            pred = model.predict(temp_input.reshape(1, *temp_input.shape), verbose=0)[0, 0]
            new_row = np.hstack([pred.reshape(-1, 1), temp_input[-1, 1:].reshape(1, -1)])
            pred_price = scaler.inverse_transform(new_row)[0, 0]
            pred_path.append(pred_price)
            temp_input = np.vstack([temp_input[1:], new_row])

            if step % 50 == 0:
                print(f"Step {step}/{steps} for path {path_num+1}...")

        predictions.append(pred_path)

    print("Prediction complete!")
    return np.array(predictions)

# Save predictions to Google Drive
def save_predictions(predictions, timestamps, filename=None):
    if filename is None:
        filename = f'/content/drive/MyDrive/predictions_{datetime.datetime.utcnow().strftime("%Y%m%d_%H%M%S")}.json'
    with open(filename, 'w') as f:
        json.dump({'timestamps': timestamps, 'predictions': predictions.tolist()}, f)
    print(f"Predictions saved in Google Drive: {filename}")
    return filename

# CRPS Calculation Function
def calculate_crps_for_miner(simulation_runs, real_price_path, time_increment):
    scoring_intervals = {
        "5min": 300,
        "30min": 1800,
        "3hour": 10800,
        "24hour_abs": 86400,
    }

    def get_interval_steps(scoring_interval, time_increment):
        return int(scoring_interval / time_increment)

    sum_all_scores = 0.0
    for interval_name, interval_seconds in scoring_intervals.items():
        interval_steps = get_interval_steps(interval_seconds, time_increment)
        simulated_changes = calculate_price_changes_over_intervals(
            simulation_runs, interval_steps, absolute_price=interval_name.endswith("_abs"))
        real_changes = calculate_price_changes_over_intervals(
            real_price_path.reshape(1, -1), interval_steps, absolute_price=interval_name.endswith("_abs"))[0]

        num_intervals = simulated_changes.shape[1]
        crps_values = np.zeros(num_intervals)
        for t in range(num_intervals):
            forecasts = simulated_changes[:, t]
            observation = real_changes[t]
            crps_values[t] = crps_ensemble(observation, forecasts)

        total_crps_interval = np.sum(crps_values)
        sum_all_scores += total_crps_interval

    return sum_all_scores

# Fetch real BTC prices after 24 hours and calculate CRPS
def fetch_real_prices_and_calculate_crps(predictions_file):
    btc_real = fetch_btc_data(interval='5m', period='1d')  # Fetch last 24 hours
    real_prices = btc_real['Close'].values[-288:]

    with open(predictions_file, 'r') as f:
        data = json.load(f)
        predictions = np.array(data['predictions'])
        timestamps = data['timestamps']

    crps_score = calculate_crps_for_miner(predictions, real_prices, 300)
    print(f"CRPS Score: {crps_score}")
    plot_real_vs_predicted(predictions, real_prices, timestamps)
    return crps_score

# Plot predicted vs actual prices
def plot_real_vs_predicted(predictions, real_prices, timestamps):
    fig = go.Figure()
    for i, path in enumerate(predictions):
        fig.add_trace(go.Scatter(x=timestamps, y=path, mode='lines', name=f'Path {i+1}'))
    fig.add_trace(go.Scatter(x=timestamps, y=real_prices, mode='lines', name='Actual Price', line=dict(color='red')))
    fig.update_layout(title='Bitcoin Price Prediction vs Actual', xaxis_title='Time', yaxis_title='Price')
    fig.show()

# Main workflow
btc_data = fetch_btc_data()
X, y, scaler = prepare_data(btc_data)
model = build_lstm_model(X.shape[1:])
model.fit(X, y, epochs=10, batch_size=32, verbose=1)
future_predictions = predict_future(model, X, scaler, num_paths=100)
timestamps = [(datetime.datetime.utcnow() + datetime.timedelta(minutes=5 * i)).isoformat() for i in range(288)]
predictions_filename = save_predictions(future_predictions, timestamps)
print("Predictions saved and plotted successfully!")

# Manually run the below after 24 hours
# crps_score = fetch_real_prices_and_calculate_crps(predictions_filename)
# Out:
# Mounted at /content/drive
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0314
# Epoch 2/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0026
# Epoch 3/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0019
# Epoch 4/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0012
# Epoch 5/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 8.3505e-04
# Epoch 6/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 6.4356e-04
# Epoch 7/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 5.7525e-04
# Epoch 8/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.7790e-04
# Epoch 9/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 4.9996e-04
# Epoch 10/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 5.0561e-04
# Generating prediction path 1/100...
# Step 0/288 for path 1...
# Step 50/288 for path 1...
# Step 100/288 for path 1...
# Step 150/288 for path 1...
# Step 200/288 for path 1...
# Step 250/288 for path 1...
# Generating prediction path 2/100...
# Step 0/288 for path 2...
# Step 50/288 for path 2...
# Step 100/288 for path 2...
# Step 150/288 for path 2...
# Step 200/288 for path 2...
# Step 250/288 for path 2...
# Generating prediction path 3/100...
# Step 0/288 for path 3...
# Step 50/288 for path 3...
# Step 100/288 for path 3...
# Step 150/288 for path 3...
# Step 200/288 for path 3...
# Step 250/288 for path 3...
# Generating prediction path 4/100...
# Step 0/288 for path 4...
# Step 50/288 for path 4...
# Step 100/288 for path 4...
# Step 150/288 for path 4...
# Step 200/288 for path 4...
# Step 250/288 for path 4...
# Generating prediction path 5/100...
# Step 0/288 for path 5...
# Step 50/288 for path 5...
# Step 100/288 for path 5...
# Step 150/288 for path 5...
# Step 200/288 for path 5...
# Step 250/288 for path 5...
# Generating prediction path 6/100...
# Step 0/288 for path 6...
# Step 50/288 for path 6...
# Step 100/288 for path 6...
# Step 150/288 for path 6...
# Step 200/288 for path 6...
# Step 250/288 for path 6...
# Generating prediction path 7/100...
# Step 0/288 for path 7...
# Step 50/288 for path 7...
# Step 100/288 for path 7...
# Step 150/288 for path 7...
# Step 200/288 for path 7...
# Step 250/288 for path 7...
# Generating prediction path 8/100...
# Step 0/288 for path 8...
# Step 50/288 for path 8...
# Step 100/288 for path 8...
# Step 150/288 for path 8...
# Step 200/288 for path 8...
# Step 250/288 for path 8...
# Generating prediction path 9/100...
# Step 0/288 for path 9...
# Step 50/288 for path 9...
# Step 100/288 for path 9...
# Step 150/288 for path 9...
# Step 200/288 for path 9...
# Step 250/288 for path 9...
# Generating prediction path 10/100...
# Step 0/288 for path 10...
# Step 50/288 for path 10...
# Step 100/288 for path 10...
# Step 150/288 for path 10...
# Step 200/288 for path 10...
# Step 250/288 for path 10...
# Generating prediction path 11/100...
# Step 0/288 for path 11...
# Step 50/288 for path 11...
# Step 100/288 for path 11...
# Step 150/288 for path 11...
# Step 200/288 for path 11...
# Step 250/288 for path 11...
# Generating prediction path 12/100...
# Step 0/288 for path 12...
# Step 50/288 for path 12...
# Step 100/288 for path 12...
# Step 150/288 for path 12...
# Step 200/288 for path 12...
# Step 250/288 for path 12...
# Generating prediction path 13/100...
# Step 0/288 for path 13...
# Step 50/288 for path 13...
# Step 100/288 for path 13...
# Step 150/288 for path 13...
# Step 200/288 for path 13...
# Step 250/288 for path 13...
# Generating prediction path 14/100...
# Step 0/288 for path 14...
# Step 50/288 for path 14...
# Step 100/288 for path 14...
# Step 150/288 for path 14...
# Step 200/288 for path 14...
# Step 250/288 for path 14...
# Generating prediction path 15/100...
# Step 0/288 for path 15...
# Step 50/288 for path 15...
# Step 100/288 for path 15...
# Step 150/288 for path 15...
# Step 200/288 for path 15...
# Step 250/288 for path 15...
# Generating prediction path 16/100...
# Step 0/288 for path 16...
# Step 50/288 for path 16...
# Step 100/288 for path 16...
# Step 150/288 for path 16...
# Step 200/288 for path 16...
# Step 250/288 for path 16...
# Generating prediction path 17/100...
# Step 0/288 for path 17...
# Step 50/288 for path 17...
# Step 100/288 for path 17...
# Step 150/288 for path 17...
# Step 200/288 for path 17...
# Step 250/288 for path 17...
# Generating prediction path 18/100...
# Step 0/288 for path 18...
# Step 50/288 for path 18...
# Step 100/288 for path 18...
# Step 150/288 for path 18...
# Step 200/288 for path 18...
# Step 250/288 for path 18...
# Generating prediction path 19/100...
# Step 0/288 for path 19...
# Step 50/288 for path 19...
# Step 100/288 for path 19...
# Step 150/288 for path 19...
# Step 200/288 for path 19...
# Step 250/288 for path 19...
# Generating prediction path 20/100...
# Step 0/288 for path 20...
# Step 50/288 for path 20...
# Step 100/288 for path 20...
# Step 150/288 for path 20...
# Step 200/288 for path 20...
# Step 250/288 for path 20...
# Generating prediction path 21/100...
# Step 0/288 for path 21...
# Step 50/288 for path 21...
# Step 100/288 for path 21...
# Step 150/288 for path 21...
# Step 200/288 for path 21...
# Step 250/288 for path 21...
# Generating prediction path 22/100...
# Step 0/288 for path 22...
# Step 50/288 for path 22...
# Step 100/288 for path 22...
# Step 150/288 for path 22...
# Step 200/288 for path 22...
# Step 250/288 for path 22...
# Generating prediction path 23/100...
# Step 0/288 for path 23...
# Step 50/288 for path 23...
# Step 100/288 for path 23...
# Step 150/288 for path 23...
# Step 200/288 for path 23...
# Step 250/288 for path 23...
# Generating prediction path 24/100...
# Step 0/288 for path 24...
# Step 50/288 for path 24...
# Step 100/288 for path 24...
# Step 150/288 for path 24...
# Step 200/288 for path 24...
# Step 250/288 for path 24...
# Generating prediction path 25/100...
# Step 0/288 for path 25...
# Step 50/288 for path 25...
# Step 100/288 for path 25...
# Step 150/288 for path 25...
# Step 200/288 for path 25...
# Step 250/288 for path 25...
# Generating prediction path 26/100...
# Step 0/288 for path 26...
# Step 50/288 for path 26...
# Step 100/288 for path 26...
# Step 150/288 for path 26...
# Step 200/288 for path 26...
# Step 250/288 for path 26...
# Generating prediction path 27/100...
# Step 0/288 for path 27...
# Step 50/288 for path 27...
# Step 100/288 for path 27...
# Step 150/288 for path 27...
# Step 200/288 for path 27...
# Step 250/288 for path 27...
# Generating prediction path 28/100...
# Step 0/288 for path 28...
# Step 50/288 for path 28...
# Step 100/288 for path 28...
# Step 150/288 for path 28...
# Step 200/288 for path 28...
# Step 250/288 for path 28...
# Generating prediction path 29/100...
# Step 0/288 for path 29...
# Step 50/288 for path 29...
# Step 100/288 for path 29...
# Step 150/288 for path 29...
# Step 200/288 for path 29...
# Step 250/288 for path 29...
# Generating prediction path 30/100...
# Step 0/288 for path 30...
# Step 50/288 for path 30...
# Step 100/288 for path 30...
# Step 150/288 for path 30...
# Step 200/288 for path 30...
# Step 250/288 for path 30...
# Generating prediction path 31/100...
# Step 0/288 for path 31...
# Step 50/288 for path 31...
# Step 100/288 for path 31...
# Step 150/288 for path 31...
# Step 200/288 for path 31...
# Step 250/288 for path 31...
# Generating prediction path 32/100...
# Step 0/288 for path 32...
# Step 50/288 for path 32...
# Step 100/288 for path 32...
# Step 150/288 for path 32...
# Step 200/288 for path 32...
# Step 250/288 for path 32...
# Generating prediction path 33/100...
# Step 0/288 for path 33...
# Step 50/288 for path 33...
# Step 100/288 for path 33...
# Step 150/288 for path 33...
# Step 200/288 for path 33...
# Step 250/288 for path 33...
# Generating prediction path 34/100...
# Step 0/288 for path 34...
# Step 50/288 for path 34...
# Step 100/288 for path 34...
# Step 150/288 for path 34...
# Step 200/288 for path 34...
# Step 250/288 for path 34...
# Generating prediction path 35/100...
# Step 0/288 for path 35...
# Step 50/288 for path 35...
# Step 100/288 for path 35...
# Step 150/288 for path 35...
# Step 200/288 for path 35...
# Step 250/288 for path 35...
# Generating prediction path 36/100...
# Step 0/288 for path 36...
# Step 50/288 for path 36...
# Step 100/288 for path 36...
# Step 150/288 for path 36...
# Step 200/288 for path 36...
# Step 250/288 for path 36...
# Generating prediction path 37/100...
# Step 0/288 for path 37...
# Step 50/288 for path 37...
# Step 100/288 for path 37...
# Step 150/288 for path 37...
# Step 200/288 for path 37...
# Step 250/288 for path 37...
# Generating prediction path 38/100...
# Step 0/288 for path 38...
# Step 50/288 for path 38...
# Step 100/288 for path 38...
# Step 150/288 for path 38...
# Step 200/288 for path 38...
# Step 250/288 for path 38...
# Generating prediction path 39/100...
# Step 0/288 for path 39...
# Step 50/288 for path 39...
# Step 100/288 for path 39...
# Step 150/288 for path 39...
# Step 200/288 for path 39...
# Step 250/288 for path 39...
# Generating prediction path 40/100...
# Step 0/288 for path 40...
# Step 50/288 for path 40...
# Step 100/288 for path 40...
# Step 150/288 for path 40...
# Step 200/288 for path 40...
# Step 250/288 for path 40...
# Generating prediction path 41/100...
# Step 0/288 for path 41...
# Step 50/288 for path 41...
# Step 100/288 for path 41...
# Step 150/288 for path 41...
# Step 200/288 for path 41...
# Step 250/288 for path 41...
# Generating prediction path 42/100...
# Step 0/288 for path 42...
# Step 50/288 for path 42...
# Step 100/288 for path 42...
# Step 150/288 for path 42...
# Step 200/288 for path 42...
# Step 250/288 for path 42...
# Generating prediction path 43/100...
# Step 0/288 for path 43...
# Step 50/288 for path 43...
# Step 100/288 for path 43...
# Step 150/288 for path 43...
# Step 200/288 for path 43...
# Step 250/288 for path 43...
# Generating prediction path 44/100...
# Step 0/288 for path 44...
# Step 50/288 for path 44...
# Step 100/288 for path 44...
# Step 150/288 for path 44...
# Step 200/288 for path 44...
# Step 250/288 for path 44...
# Generating prediction path 45/100...
# Step 0/288 for path 45...
# Step 50/288 for path 45...
# Step 100/288 for path 45...
# Step 150/288 for path 45...
# Step 200/288 for path 45...
# Step 250/288 for path 45...
# Generating prediction path 46/100...
# Step 0/288 for path 46...
# Step 50/288 for path 46...
# Step 100/288 for path 46...
# Step 150/288 for path 46...
# Step 200/288 for path 46...
# Step 250/288 for path 46...
# Generating prediction path 47/100...
# Step 0/288 for path 47...
# Step 50/288 for path 47...
# Step 100/288 for path 47...
# Step 150/288 for path 47...
# Step 200/288 for path 47...
# Step 250/288 for path 47...
# Generating prediction path 48/100...
# Step 0/288 for path 48...
# Step 50/288 for path 48...
# Step 100/288 for path 48...
# Step 150/288 for path 48...
# Step 200/288 for path 48...
# Step 250/288 for path 48...
# Generating prediction path 49/100...
# Step 0/288 for path 49...
# Step 50/288 for path 49...
# Step 100/288 for path 49...
# Step 150/288 for path 49...
# Step 200/288 for path 49...
# Step 250/288 for path 49...
# Generating prediction path 50/100...
# Step 0/288 for path 50...
# Step 50/288 for path 50...
# Step 100/288 for path 50...
# Step 150/288 for path 50...
# Step 200/288 for path 50...
# Step 250/288 for path 50...
# Generating prediction path 51/100...
# Step 0/288 for path 51...
# Step 50/288 for path 51...
# Step 100/288 for path 51...
# Step 150/288 for path 51...
# Step 200/288 for path 51...
# Step 250/288 for path 51...
# Generating prediction path 52/100...
# Step 0/288 for path 52...
# Step 50/288 for path 52...
# Step 100/288 for path 52...
# Step 150/288 for path 52...
# Step 200/288 for path 52...
# Step 250/288 for path 52...
# Generating prediction path 53/100...
# Step 0/288 for path 53...
# Step 50/288 for path 53...
# Step 100/288 for path 53...
# Step 150/288 for path 53...
# Step 200/288 for path 53...
# Step 250/288 for path 53...
# Generating prediction path 54/100...
# Step 0/288 for path 54...
# Step 50/288 for path 54...
# Step 100/288 for path 54...
# Step 150/288 for path 54...
# Step 200/288 for path 54...
# Step 250/288 for path 54...
# Generating prediction path 55/100...
# Step 0/288 for path 55...
# Step 50/288 for path 55...
# Step 100/288 for path 55...
# Step 150/288 for path 55...
# Step 200/288 for path 55...
# Step 250/288 for path 55...
# Generating prediction path 56/100...
# Step 0/288 for path 56...
# Step 50/288 for path 56...
# Step 100/288 for path 56...
# Step 150/288 for path 56...
# Step 200/288 for path 56...
# Step 250/288 for path 56...
# Generating prediction path 57/100...
# Step 0/288 for path 57...
# Step 50/288 for path 57...
# Step 100/288 for path 57...
# Step 150/288 for path 57...
# Step 200/288 for path 57...
# Step 250/288 for path 57...
# Generating prediction path 58/100...
# Step 0/288 for path 58...
# Step 50/288 for path 58...
# Step 100/288 for path 58...
# Step 150/288 for path 58...
# Step 200/288 for path 58...
# Step 250/288 for path 58...
# Generating prediction path 59/100...
# Step 0/288 for path 59...
# Step 50/288 for path 59...
# Step 100/288 for path 59...
# Step 150/288 for path 59...
# Step 200/288 for path 59...
# Step 250/288 for path 59...
# Generating prediction path 60/100...
# Step 0/288 for path 60...
# Step 50/288 for path 60...
# Step 100/288 for path 60...
# Step 150/288 for path 60...
# Step 200/288 for path 60...
# Step 250/288 for path 60...
# Generating prediction path 61/100...
# Step 0/288 for path 61...
# Step 50/288 for path 61...
# Step 100/288 for path 61...
# Step 150/288 for path 61...
# Step 200/288 for path 61...
# Step 250/288 for path 61...
# Generating prediction path 62/100...
# Step 0/288 for path 62...
# Step 50/288 for path 62...
# Step 100/288 for path 62...
# Step 150/288 for path 62...
# Step 200/288 for path 62...
# Step 250/288 for path 62...
# Generating prediction path 63/100...
# Step 0/288 for path 63...
# Step 50/288 for path 63...
# Step 100/288 for path 63...
# Step 150/288 for path 63...
# Step 200/288 for path 63...
# Step 250/288 for path 63...
# Generating prediction path 64/100...
# Step 0/288 for path 64...
# Step 50/288 for path 64...
# Step 100/288 for path 64...
# Step 150/288 for path 64...
# Step 200/288 for path 64...
# Step 250/288 for path 64...
# Generating prediction path 65/100...
# Step 0/288 for path 65...
# Step 50/288 for path 65...
# Step 100/288 for path 65...
# Step 150/288 for path 65...
# Step 200/288 for path 65...
# Step 250/288 for path 65...
# Generating prediction path 66/100...
# Step 0/288 for path 66...
# Step 50/288 for path 66...
# Step 100/288 for path 66...
# Step 150/288 for path 66...
# Step 200/288 for path 66...
# Step 250/288 for path 66...
# Generating prediction path 67/100...
# Step 0/288 for path 67...
# Step 50/288 for path 67...
# Step 100/288 for path 67...
# Step 150/288 for path 67...
# Step 200/288 for path 67...
# Step 250/288 for path 67...
# Generating prediction path 68/100...
# Step 0/288 for path 68...
# Step 50/288 for path 68...
# Step 100/288 for path 68...
# Step 150/288 for path 68...
# Step 200/288 for path 68...
# Step 250/288 for path 68...
# Generating prediction path 69/100...
# Step 0/288 for path 69...
# Step 50/288 for path 69...
# Step 100/288 for path 69...
# Step 150/288 for path 69...
# Step 200/288 for path 69...
# Step 250/288 for path 69...
# Generating prediction path 70/100...
# Step 0/288 for path 70...
# Step 50/288 for path 70...
# Step 100/288 for path 70...
# Step 150/288 for path 70...
# Step 200/288 for path 70...
# Step 250/288 for path 70...
# Generating prediction path 71/100...
# Step 0/288 for path 71...
# Step 50/288 for path 71...
# Step 100/288 for path 71...
# Step 150/288 for path 71...
# Step 200/288 for path 71...
# Step 250/288 for path 71...
# Generating prediction path 72/100...
# Step 0/288 for path 72...
# Step 50/288 for path 72...
# Step 100/288 for path 72...
# Step 150/288 for path 72...
# Step 200/288 for path 72...
# Step 250/288 for path 72...
# Generating prediction path 73/100...
# Step 0/288 for path 73...
# Step 50/288 for path 73...
# Step 100/288 for path 73...
# Step 150/288 for path 73...
# Step 200/288 for path 73...
# Step 250/288 for path 73...
# Generating prediction path 74/100...
# Step 0/288 for path 74...
# Step 50/288 for path 74...
# Step 100/288 for path 74...
# Step 150/288 for path 74...
# Step 200/288 for path 74...
# Step 250/288 for path 74...
# Generating prediction path 75/100...
# Step 0/288 for path 75...
# Step 50/288 for path 75...
# Step 100/288 for path 75...
# Step 150/288 for path 75...
# Step 200/288 for path 75...
# Step 250/288 for path 75...
# Generating prediction path 76/100...
# Step 0/288 for path 76...
# Step 50/288 for path 76...
# Step 100/288 for path 76...
# Step 150/288 for path 76...
# Step 200/288 for path 76...
# Step 250/288 for path 76...
# Generating prediction path 77/100...
# Step 0/288 for path 77...
# Step 50/288 for path 77...
# Step 100/288 for path 77...
# Step 150/288 for path 77...
# Step 200/288 for path 77...
# Step 250/288 for path 77...
# Generating prediction path 78/100...
# Step 0/288 for path 78...
# Step 50/288 for path 78...
# Step 100/288 for path 78...
# Step 150/288 for path 78...
# Step 200/288 for path 78...
# Step 250/288 for path 78...
# Generating prediction path 79/100...
# Step 0/288 for path 79...
# Step 50/288 for path 79...
# Step 100/288 for path 79...
# Step 150/288 for path 79...
# Step 200/288 for path 79...
# Step 250/288 for path 79...
# Generating prediction path 80/100...
# Step 0/288 for path 80...
# Step 50/288 for path 80...
# Step 100/288 for path 80...
# Step 150/288 for path 80...
# Step 200/288 for path 80...
# Step 250/288 for path 80...
# Generating prediction path 81/100...
# Step 0/288 for path 81...
# Step 50/288 for path 81...
# Step 100/288 for path 81...
# Step 150/288 for path 81...
# Step 200/288 for path 81...
# Step 250/288 for path 81...
# Generating prediction path 82/100...
# Step 0/288 for path 82...
# Step 50/288 for path 82...
# Step 100/288 for path 82...
# Step 150/288 for path 82...
# Step 200/288 for path 82...
# Step 250/288 for path 82...
# Generating prediction path 83/100...
# Step 0/288 for path 83...
# Step 50/288 for path 83...
# Step 100/288 for path 83...
# Step 150/288 for path 83...
# Step 200/288 for path 83...
# Step 250/288 for path 83...
# Generating prediction path 84/100...
# Step 0/288 for path 84...
# Step 50/288 for path 84...
# Step 100/288 for path 84...
# Step 150/288 for path 84...
# Step 200/288 for path 84...
# Step 250/288 for path 84...
# Generating prediction path 85/100...
# Step 0/288 for path 85...
# Step 50/288 for path 85...
# Step 100/288 for path 85...
# Step 150/288 for path 85...
# Step 200/288 for path 85...
# Step 250/288 for path 85...
# Generating prediction path 86/100...
# Step 0/288 for path 86...
# Step 50/288 for path 86...
# Step 100/288 for path 86...
# Step 150/288 for path 86...
# Step 200/288 for path 86...
# Step 250/288 for path 86...
# Generating prediction path 87/100...
# Step 0/288 for path 87...
# Step 50/288 for path 87...
# Step 100/288 for path 87...
# Step 150/288 for path 87...
# Step 200/288 for path 87...
# Step 250/288 for path 87...
# Generating prediction path 88/100...
# Step 0/288 for path 88...
# Step 50/288 for path 88...
# Step 100/288 for path 88...
# Step 150/288 for path 88...
# Step 200/288 for path 88...
# Step 250/288 for path 88...
# Generating prediction path 89/100...
# Step 0/288 for path 89...
# Step 50/288 for path 89...
# Step 100/288 for path 89...
# Step 150/288 for path 89...
# Step 200/288 for path 89...
# Step 250/288 for path 89...
# Generating prediction path 90/100...
# Step 0/288 for path 90...
# Step 50/288 for path 90...
# Step 100/288 for path 90...
# Step 150/288 for path 90...
# Step 200/288 for path 90...
# Step 250/288 for path 90...
# Generating prediction path 91/100...
# Step 0/288 for path 91...
# Step 50/288 for path 91...
# Step 100/288 for path 91...
# Step 150/288 for path 91...
# Step 200/288 for path 91...
# Step 250/288 for path 91...
# Generating prediction path 92/100...
# Step 0/288 for path 92...
# Step 50/288 for path 92...
# Step 100/288 for path 92...
# Step 150/288 for path 92...
# Step 200/288 for path 92...
# Step 250/288 for path 92...
# Generating prediction path 93/100...
# Step 0/288 for path 93...
# Step 50/288 for path 93...
# Step 100/288 for path 93...
# Step 150/288 for path 93...
# Step 200/288 for path 93...
# Step 250/288 for path 93...
# Generating prediction path 94/100...
# Step 0/288 for path 94...
# Step 50/288 for path 94...
# Step 100/288 for path 94...
# Step 150/288 for path 94...
# Step 200/288 for path 94...
# Step 250/288 for path 94...
# Generating prediction path 95/100...
# Step 0/288 for path 95...
# Step 50/288 for path 95...
# Step 100/288 for path 95...
# Step 150/288 for path 95...
# Step 200/288 for path 95...
# Step 250/288 for path 95...
# Generating prediction path 96/100...
# Step 0/288 for path 96...
# Step 50/288 for path 96...
# Step 100/288 for path 96...
# Step 150/288 for path 96...
# Step 200/288 for path 96...
# Step 250/288 for path 96...
# Generating prediction path 97/100...
# Step 0/288 for path 97...
# Step 50/288 for path 97...
# Step 100/288 for path 97...
# Step 150/288 for path 97...
# Step 200/288 for path 97...
# Step 250/288 for path 97...
# Generating prediction path 98/100...
# Step 0/288 for path 98...
# Step 50/288 for path 98...
# Step 100/288 for path 98...
# Step 150/288 for path 98...
# Step 200/288 for path 98...
# Step 250/288 for path 98...
# Generating prediction path 99/100...
# Step 0/288 for path 99...
# Step 50/288 for path 99...
# Step 100/288 for path 99...
# Step 150/288 for path 99...
# Step 200/288 for path 99...
# Step 250/288 for path 99...
# Generating prediction path 100/100...
# Step 0/288 for path 100...
# Step 50/288 for path 100...
# Step 100/288 for path 100...
# Step 150/288 for path 100...
# Step 200/288 for path 100...
# Step 250/288 for path 100...
# Prediction complete!
# Predictions saved in Google Drive: /content/drive/MyDrive/predictions_20250303_102631.json
# Predictions saved and plotted successfully!

# %% [markdown]
# nstructions for Running the Updated Script
# 1 Run the Full Script Now
# Yes, you need to run the entire updated script to:  Fetch BTC data
# Train the LSTM model
#  Generate 100 prediction paths
#  Save the predictions to Google Drive
#
#  Run the entire script in Colab now.
#
#  What to Do After 24 Hours
# After 24 hours, you only need to run this single line in Colab

# %%
pip install properscoring
# Out:
# Collecting properscoring
#   Downloading properscoring-0.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.13.1)
# Downloading properscoring-0.1-py2.py3-none-any.whl (23 kB)
# Installing collected packages: properscoring
# Successfully installed properscoring-0.1

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from properscoring import crps_ensemble

# %%
def calculate_crps_for_miner(simulation_runs, real_price_path, time_increment):
    scoring_intervals = {
        "5min": 300,
        "30min": 1800,
        "3hour": 10800,
        "24hour_abs": 86400,
    }

    def get_interval_steps(scoring_interval, time_increment):
        return int(scoring_interval / time_increment)

    sum_all_scores = 0.0
    for interval_name, interval_seconds in scoring_intervals.items():
        interval_steps = get_interval_steps(interval_seconds, time_increment)

        # Ensure we only use the valid range of data
        simulated_changes = calculate_price_changes_over_intervals(
            simulation_runs, interval_steps, absolute_price=interval_name.endswith("_abs")
        )
        real_changes = calculate_price_changes_over_intervals(
            real_price_path.reshape(1, -1), interval_steps, absolute_price=interval_name.endswith("_abs")
        )[0]

        num_intervals = min(simulated_changes.shape[1], len(real_changes))  # Adjust to valid size
        crps_values = np.zeros(num_intervals)

        for t in range(num_intervals):
            forecasts = simulated_changes[:, t]
            observation = real_changes[t]
            crps_values[t] = crps_ensemble(observation, forecasts)

        total_crps_interval = np.sum(crps_values)
        sum_all_scores += total_crps_interval

    return sum_all_scores

# %%
predictions_filename = "/content/drive/MyDrive/predictions_20250303_102631.json"  # Update if needed
crps_score = fetch_real_prices_and_calculate_crps(predictions_filename)
# Out:
# [*********************100%***********************]  1 of 1 completed
# CRPS Score: 35151.02746172808
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="10913a82-38e7-4fab-b776-c114cf9eb8a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10913a82-38e7-4fab-b776-c114cf9eb8a9")) {                    Plotly.newPlot(                        "10913a82-38e7-4fab-b776-c114cf9eb8a9",                        [{"mode":"lines","name":"Path 1","x":["2025-03-03T10:26:31.975489","2025-03-03T10:31:31.975501","2025-03-03T10:36:31.975504","2025-03-03T10:41:31.975507","2025-03-03T10:46:31.975509","2025-03-03T10:51:31.975512","2025-03-03T10:56:31.975515","2025-03-03T11:01:31.975519","2025-03-03T11:06:31.975522","2025-03-03T11:11:31.975525","2025-03-03T11:16:31.975527","2025-03-03T11:21:31.975529","2025-03-03T11:26:31.975532","2025-03-03T11:31:31.975534","2025-03-03T11:36:31.975536","2025-03-03T11:41:31.975538","2025-03-03T11:46:31.975540","2025-03-03T11:51:31.975554","2025-03-03T11:56:31.975556","2025-03-03T12:01:31.975559","2025-03-03T12:06:31.975561","2025-03-03T12:11:31.975563","2025-03-03T12:16:31.975565","2025-03-03T12:21:31.975568","2025-03-03T12:26:31.975570","2025-03-03T12:31:31.975572","2025-03-03T12:36:31.975575","2025-03-03T12:41:31.975577","2025-03-03T12:46:31.975579","2025-03-03T12:51:31.975581","2025-03-03T12:56:31.975583","2025-03-03T13:01:31.975586","2025-03-03T13:06:31.975588","2025-03-03T13:11:31.975590","2025-03-03T13:16:31.975593","2025-03-03T13:21:31.975595","2025-03-03T13:26:31.975597","2025-03-03T13:31:31.975599","2025-03-03T13:36:31.975602","2025-03-03T13:41:31.975604","2025-03-03T13:46:31.975606","2025-03-03T13:51:31.975609","2025-03-03T13:56:31.975611","2025-03-03T14:01:31.975615","2025-03-03T14:06:31.975619","2025-03-03T14:11:31.975624","2025-03-03T14:16:31.975628","2025-03-03T14:21:31.975631","2025-03-03T14:26:31.975635","2025-03-03T14:31:31.975639","2025-03-03T14:36:31.975642","2025-03-03T14:41:31.975646","2025-03-03T14:46:31.975869","2025-03-03T14:51:31.975873","2025-03-03T14:56:31.975875","2025-03-03T15:01:31.975878","2025-03-03T15:06:31.975880","2025-03-03T15:11:31.975882","2025-03-03T15:16:31.975884","2025-03-03T15:21:31.975886","2025-03-03T15:26:31.975889","2025-03-03T15:31:31.975891","2025-03-03T15:36:31.975893","2025-03-03T15:41:31.975895","2025-03-03T15:46:31.975898","2025-03-03T15:51:31.975901","2025-03-03T15:56:31.975903","2025-03-03T16:01:31.975905","2025-03-03T16:06:31.975907","2025-03-03T16:11:31.975910","2025-03-03T16:16:31.975912","2025-03-03T16:21:31.975914","2025-03-03T16:26:31.975916","2025-03-03T16:31:31.975919","2025-03-03T16:36:31.975921","2025-03-03T16:41:31.975923","2025-03-03T16:46:31.975926","2025-03-03T16:51:31.975929","2025-03-03T16:56:31.975931","2025-03-03T17:01:31.975933","2025-03-03T17:06:31.975935","2025-03-03T17:11:31.975938","2025-03-03T17:16:31.975940","2025-03-03T17:21:31.975942","2025-03-03T17:26:31.975944","2025-03-03T17:31:31.975947","2025-03-03T17:36:31.975949","2025-03-03T17:41:31.975951","2025-03-03T17:46:31.975953","2025-03-03T17:51:31.975956","2025-03-03T17:56:31.975958","2025-03-03T18:01:31.975960","2025-03-03T18:06:31.975962","2025-03-03T18:11:31.975965","2025-03-03T18:16:31.975968","2025-03-03T18:21:31.975970","2025-03-03T18:26:31.975972","2025-03-03T18:31:31.975975","2025-03-03T18:36:31.975977","2025-03-03T18:41:31.975979","2025-03-03T18:46:31.975982","2025-03-03T18:51:31.975984","2025-03-03T18:56:31.975986","2025-03-03T19:01:31.975989","2025-03-03T19:06:31.975991","2025-03-03T19:11:31.975993","2025-03-03T19:16:31.975996","2025-03-03T19:21:31.975998","2025-03-03T19:26:31.976000","2025-03-03T19:31:31.976007","2025-03-03T19:36:31.976009","2025-03-03T19:41:31.976011","2025-03-03T19:46:31.976014","2025-03-03T19:51:31.976016","2025-03-03T19:56:31.976034","2025-03-03T20:01:31.976039","2025-03-03T20:06:31.976043","2025- ...
