# %% [markdown]
# <a href="https://colab.research.google.com/github/awaiskhan005/DEEP-LEARNING-AND-FORECASTING/blob/main/UMAR_sha_10_COINS_Prediction_mock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime, timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# Constants
CRYPTO_SYMBOLS = ['BTC-USD', 'ETH-USD', 'BNB-USD', 'XRP-USD', 'ADA-USD', 'DOGE-USD', 'SOL-USD', 'DOT-USD', 'MATIC-USD', 'LTC-USD']
LOOKBACK_DAYS = 60
PREDICT_DAYS = 1
API_KEY = "YOUR_NEWS_API_KEY"  # Replace with an actual API Key
FREE_NEWS_API = "https://free-news.p.rapidapi.com/v1/search"

# Fetch historical price data
def fetch_crypto_data(symbol, start_date, end_date):
    df = yf.download(symbol, start=start_date, end=end_date, interval='1d')
    df = df[['Close']]
    df.dropna(inplace=True)

    # Adding Technical Indicators
    df['SMA_10'] = df['Close'].rolling(window=10).mean()
    df['SMA_50'] = df['Close'].rolling(window=50).mean()
    df['RSI'] = calculate_rsi(df['Close'], 14)
    df['MACD'] = df['Close'].ewm(span=12, adjust=False).mean() - df['Close'].ewm(span=26, adjust=False).mean()
    df.dropna(inplace=True)
    return df

# Calculate RSI
def calculate_rsi(series, period=14):
    delta = series.diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=period).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=period).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

# Predict Future Prices
def predict_price(model, X_test, scaler):
    predictions = model.predict(X_test)

    # Ensure predictions are correctly reshaped for inverse transformation
    predictions_reshaped = np.zeros((predictions.shape[0], scaler.n_features_in_))
    predictions_reshaped[:, 0] = predictions.flatten()

    return scaler.inverse_transform(predictions_reshaped)[:, 0]  # Extract only the price column

# Main Execution
if __name__ == "__main__":
    start_date = (datetime.today() - timedelta(days=365 * 2)).strftime('%Y-%m-%d')
    end_date = datetime.today().strftime('%Y-%m-%d')

    all_predictions = {}

    for symbol in CRYPTO_SYMBOLS:
        print(f"Processing {symbol}...")
        df = fetch_crypto_data(symbol, start_date, end_date)
        sentiment_score = fetch_news_sentiment(symbol.split('-')[0])

        df['Sentiment'] = sentiment_score
        X, y, scaler = preprocess_data(df)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

        model = train_model(X_train, y_train)
        predicted_prices = predict_price(model, X_test, scaler)

        all_predictions[symbol] = predicted_prices

    # Visualizing Predictions
    plt.figure(figsize=(10, 6))
    for symbol, predictions in all_predictions.items():
        plt.plot(predictions, label=f'{symbol} Prediction')
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.legend()
    plt.title('Predicted Crypto Prices')
    plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Processing BTC-USD...
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - loss: 0.0827
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0065
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0060
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0039
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0031
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0030
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0025
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0021
# Epoch 9/50
# ...
